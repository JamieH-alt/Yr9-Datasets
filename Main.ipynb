# %% [markdown]
# ---
#
# # My Work
#
# ---
#
# ## Identifying And Defining
#
# ---
#
# ### Key Details
#
# * Data: \
#  = I am using Open Meteo's data API to look at the temperature over the course of a year. (If possible)
# * Goal: \
#  = To identify the coldest days and warmest days to see when seasons mainly pick up (As they have a bit of overlap, e.g. Summer starts cold, Winter starts warm)
# * Source: \
#  = https://open-meteo.com/en/
# * Access: \
#  = Public as long as you know how to use an API.
# * Access Method: \
#  = Via its online API service.
#
# ---
#
# ### Functional Requirements
# * Loading \
#  = The API needs to let me obtain large amounts of data as I'm attempting to look at the weather of a year period. And it all needs to be formatted correctly so it loads easily into pandas.
# * Data Cleaning \
#  = The system shouldn't need any data cleaning as it appears to be well maintained
# * Data Analysis \
#  = The system needs to allow for mean averaging (And potentially linear regression if I have the time.)
# * Data Visualisation \
#  = The data visualisation has not yet been finalised but it will most likely be through Matplotlib or some other similar aplication.
# * Data Reporting \
#  = The system should output the charts to the screen and it shouldn't need to store anything as a TXT unless needed.
#
# ---
#
#  ### Use Cases
# * Loading \
# --  Actor: User \
# --  Goal: To choose which dataset to load into the system \
# --  Preconditions: User knows the format in which this needs to be inputed (Name of place) \
# --  Main Flow: \
# ------  1. User inputs the location into the right spot in the User interface. \
# ------  2. User inputs a valid year into the right spot in the User interface. \
# ------  3. System validates the link. \
# ------  4. System loads the dataset and proccesses into a chart. \
# --  Postconditions: Dataset is loaded and shown to the user as a chart.
# * Data Reporting \
# --  Actor: User \
# --  Goal: To decide whether or not to save a file, and to name that file. \
# --  Preconditions: User has already loaded an data using an API call from the `Loading` Section \
# --  Main Flow: \
# ------  1. User inputs a file name into the selection box \
# ------  2. User hits save. \
# --  Postconditions: Dataset is saved as a file with the name input by the User.
#
# ---
#
# ### Non-Functional Requirements
# * Usability: \
#  = The Userinterface needs to be non-eyehurting (aestheticly pleasing), easy to navigate and shouldn't require any thought to use. \
#  = The README document should supply an example of the program being used aswell as a link to the documentation of the Open Meteo API.
# * Reliability: \
#  = Little is required from the system when it comes to errors. Mainly just telling the user when a link is incorrect or when an internal error has occured. Thanks to users not having any access to actually interact with the data beyond looking at it; data integrity is a non-issue. \
#  = Data Accuracy is a requirement especially if I get into linear regression. But also the program should output the difference between the mean of the months and the median to compare those datapoints.
#
# ---
#
# ## Researching And Planning
#
# ---
#
# ### Research of Chosen Issue
# * Purpose: \
#  = The key purpose of my project is to identify the days of each month when the temperature changes to match the season; this is important as it helps meteorologists predict how much rain the next winter might bring, how far sea levels will rise due to warmer sea temperatures. Aswell as for the average joe letting them understand what sort of temperature extremities are forecasted.
# * Missing Data: \
#  = Currently there isn't an easy way to compare trends in weather between locations and times. Allowing for any thing
# * Stakeholders: \
#  = Like previously stated indivduals and meteorologists will benefit from the information I create. Less so meteorologists as I'd imagine they already have the tools to process this data to a higher level than I can, but the resource is still open for them. The information I get from the data analysis is important for an individual to understand what's happening to our climate.
# * Use: \
#  = The stakeholders are able to use the information I create to gain a better understanding of our climate and how its changing aswell as giving them the information needed to prepare themselves for upcoming changes in temperature by following trends.
#
# ---
#
# ### Privacy And Security
# * Application Data Privacy: \
#  = My application does not collect any data from the user. And everything searched is stored on the users computer. The closest to identifiable data that the program requires is a city that the user inputs to pull the data from. There are also zero foreseeable changes/responsibilites that I'd need to make if I was to push this application to the public.
# * Cyber Security: \
#  = A normal application should have many things in order to maintain the security of its users. It should have User Authentication, Password Hashing and Encryption to keep all personally identifiable details of the user safe. \
#  = User Authentication is the process in which a persons identified is verified before they are allowed access to an online service.
#  = Password Hashing is where passwords are changed mathematically before being stored. There's no way to reverse the process and the code for it is stored on the users application. When User Authentication occurs it checks a hashed password against the hashed password saved in the server; allowing a process in which the password itself is never sent across the internet. \
#  = Encryption is a way to scramble/change/mix data so that only authorised parties with an "Encryption Key" can unscramble and read it.
#
#
# ---
#
# ### Data Dictionary
#
# | Field | Datatype | Format for Display | Description | Example | Validation |
# | --- | --- | --- | --- | --- | --- |
# | longitude | float64 | (+/-)XXX.XX... | The longitudial place of the inputed city | 151.3417 | A valid longitudial coordinate |
# | latitude | float64 | (+/-)XXX.XX... | The latitudial place of the inputed city | -33.4267 | A valid latitudial coordinate |
# | time | datetime64 | YYYY-MM-DD HH:MM | Time of the data being recorded | 2024-08-05 10:30 | Must be a valid time. |
# | temperature (celcius) | float64 | NN.NN... | Temperature recorded at the location at the stated time | 31.24 | Must be a decimal number |
#
# ---
#
# ## Testing And Evaluation
#
# ---
#
# ### Data Visualisation
# ![image.png](attachment:image.png)
# This is an example that shows data being mapped from Sydney, Toronto, England, France and Poland. \
# Its the temperatures of each of these locations since around sometime in May to 19/08/2024 (Today)
#
# ---
#
# ### Calculations
# There is no real math in my program as its made just for day to day comparisons and trends in weather.
#
# ---
#
# ### Accuracy
# The data I provided is highly accurate as it comes from the OpenMeteo database, and the GeoPy database. \
# GeoPy gives a set of longitude and latitude coordinates for the inputed names and then that is input into Open Meteo. \
# OpenMeteo then gets the temperature of those longitude and latitude coordinates based on math taken from their nearest few physical data points.
#
# ---
#
# ### Conclusions
# Conclusions are all up to the user to draw. But with our data the type of conclusions we can draw are pretty simple. First we can see what kind of temperatures we can expect to continue throughout the month. Second we can see the difference of temperatures between locations. (This is less useful on places that are in different hemispheres. And very short distances.) Allowing us to see that some locations are often colder or warmer than others. \
# In the example I provided you can see that Sydney has the lowest temperatures, most likely because its in winter. And that France has the most fluctuating temperatures.
#
# ---
#
# ### Peer Evaluation
#
# ---
#
# ### Evaluation of Final Produc in Relation to Functional and Non-Functional Requirements
#
# ### Resources Used:
# Nation Centre for Atmospheric Science (United Kingdom) \
# https://ncas.ac.uk/learn/why-is-climate-important/
